# %% [markdown]
# ### Created By : Zaid Ahmed Zardi

# %% [markdown]
# #### Problem statement:
# To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %% [markdown]
# ### Importing Skin Cancer Data

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
## Paths of train and test dataset on Google drive

data_dir_train = pathlib.Path("/content/gdrive/My Drive/Melanoma Detection Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path("/content/gdrive/My Drive/Melanoma Detection Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test")

## Paths of train and test dataset on local machine
# data_dir_train = pathlib.Path("Skin cancer ISIC The International Skin Imaging Collaboration/Train")
# data_dir_test = pathlib.Path("Skin cancer ISIC The International Skin Imaging Collaboration/Test")

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Note:seed=123  using tf.keras.preprocessing.image_dataset_from_directory

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split = 0.2,
    subset='training',
    image_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split = 0.2,
    subset='validation',
    image_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and storing them in a list.


class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

### your code goes here, you can use training or validation data to visualize

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Your code goes here

# Number of target labels are 9
target_labels = 9

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)), # Changed: Removed 'experimental.preprocessing.'
  layers.Conv2D(16, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Conv2D(32, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Conv2D(64, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation=tf.nn.relu),
  layers.Dense(target_labels)
])

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling_1 (Rescaling)              │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 180, 180, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 90, 90, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 90, 90, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 45, 45, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 45, 45, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 30976)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │       3,965,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 9)                   │           1,161 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,989,801 (15.22 MB)
#  Trainable params: 3,989,801 (15.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Train the model

# %%
# %%time
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 483s 3s/step - accuracy: 0.2301 - loss: 2.2002 - val_accuracy: 0.3333 - val_loss: 1.8205
# Epoch 2/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.3542 - loss: 1.7653 - val_accuracy: 0.4362 - val_loss: 1.7409
# Epoch 3/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.4543 - loss: 1.5543 - val_accuracy: 0.4430 - val_loss: 1.6003
# Epoch 4/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5189 - loss: 1.4249 - val_accuracy: 0.5436 - val_loss: 1.4123
# Epoch 5/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5449 - loss: 1.2979 - val_accuracy: 0.4944 - val_loss: 1.5357
# Epoch 6/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5948 - loss: 1.1898 - val_accuracy: 0.5235 - val_loss: 1.4686
# Epoch 7/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6009 - loss: 1.1362 - val_accuracy: 0.4922 - val_loss: 1.4642
# Epoch 8/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.6136 - loss: 1.0377 - val_accuracy: 0.5145 - val_loss: 1.4485
# Epoch 9/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6258 - loss: 1.0554 - val_accuracy: 0.5168 - val_loss: 1.4557
# Epoch 10/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7090 - loss: 0.8512 - val_accuracy: 0.5369 - val_loss: 1.5971
# Epoch 11/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7213 - loss: 0.7892 - val_accuracy: 0.5347 - val_loss: 1.5339
# Epoch 12/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7422 - loss: 0.7203 - val_accuracy: 0.5078 - val_loss: 1.5080
# Epoch 13/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7733 - loss: 0.6599 - val_accuracy: 0.5503 - val_loss: 1.8963
# Epoch 14/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7732 - loss: 0.5902 - val_accuracy: 0.5459 - val_loss: 1.7641
# Epoch 15/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8410 - loss: 0.4420 - val_accuracy: 0.5235 - val_loss: 2.0587
# Epoch 16/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8549 - loss: 0.4003 - val_accuracy: 0.5481 - val_loss: 2.0621
# Epoch 17/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8724 - loss: 0.3616 - val_accuracy: 0.5168 - val_loss: 2.1857
# Epoch 18/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8879 - loss: 0.2933 - val_accuracy: 0.5235 - val_loss: 2.3126
# Epoch 19/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8689 - loss: 0.3522 - val_accuracy: 0.5123 - val_loss: 2.3072
# Epoch 20/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8577 - loss: 0.3479 - val_accuracy: 0.5369 - val_loss: 2.1578
# CPU times: user 41.8 s, sys: 2.49 s, total: 44.2 s
# Wall time: 8min 25s

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ### Write your findings here

# %% [markdown]
# ***Observations:***
#
# 1. The model's training accuracy shows a steady increase of upto 90%, while validation accuracy remains consistently around 55%.
#
# 2. A high training accuracy suggests the model has effectively captured the noise within the data. However, its poor performance on validation data indicates a lack of generalizability.
#
# 3. These observations confirm the presence of overfitting. To address this issue, augmentation techniques will be employed. Given the limited training data available, new samples will be generated by making slight modifications to existing data (such as horizontal/vertical image flipping, minor image rotations, etc.), which will then be used for training the model.

# %%
# After you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy.
# Your code goes here
import tensorflow as tf
augmentation_data = tf.keras.Sequential([
                                      tf.keras.layers.RandomFlip("horizontal", input_shape=(img_height, img_width, 3)), # Changed layers.experimental.preprocessing to layers.preprocessing
                                      tf.keras.layers.RandomRotation(0.1), # Changed layers.experimental.preprocessing to layers.preprocessing
                                      tf.keras.layers.RandomZoom(0.1), # Changed layers.experimental.preprocessing to layers.preprocessing
])

# %%
# Visualize how your augmentation strategy works for one instance of training image.
# Your code goes here

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        augmented_images = augmentation_data(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.title(class_names[labels[0]])
        plt.axis("off")

# %% [markdown]
# ### Create the model, compile and train the model

# %%
model = Sequential([
    augmentation_data,
    layers.Rescaling(1./255),  # Changed to layers.Rescaling
    layers.Conv2D(16, (3, 3), padding='same', activation=tf.nn.relu),
    layers.MaxPooling2D(),
    layers.Conv2D(32, (3, 3), padding='same', activation=tf.nn.relu),
    layers.MaxPooling2D(),
    layers.Conv2D(64, (3, 3), padding='same', activation=tf.nn.relu),
    layers.MaxPooling2D(),
    layers.Dropout(0.2),
    layers.Flatten(),
    layers.Dense(128, activation=tf.nn.relu),
    layers.Dense(target_labels)
])

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
# %%time
## Your code goes here, note: train your model for 20 epochs
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 0.2555 - loss: 2.0200 - val_accuracy: 0.3512 - val_loss: 1.7862
# Epoch 2/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.3937 - loss: 1.6913 - val_accuracy: 0.4452 - val_loss: 1.5951
# Epoch 3/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.4910 - loss: 1.4756 - val_accuracy: 0.5369 - val_loss: 1.3849
# Epoch 4/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.5168 - loss: 1.3884 - val_accuracy: 0.5145 - val_loss: 1.4461
# Epoch 5/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.5210 - loss: 1.3144 - val_accuracy: 0.5011 - val_loss: 1.5196
# Epoch 6/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.5442 - loss: 1.3235 - val_accuracy: 0.4922 - val_loss: 1.5546
# Epoch 7/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.5430 - loss: 1.3068 - val_accuracy: 0.5481 - val_loss: 1.3015
# Epoch 8/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.5546 - loss: 1.2302 - val_accuracy: 0.5503 - val_loss: 1.3268
# Epoch 9/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.5358 - loss: 1.2502 - val_accuracy: 0.4787 - val_loss: 1.5000
# Epoch 10/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.5236 - loss: 1.2831 - val_accuracy: 0.4743 - val_loss: 1.5128
# Epoch 11/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.5516 - loss: 1.2510 - val_accuracy: 0.5369 - val_loss: 1.3709
# Epoch 12/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5619 - loss: 1.2036 - val_accuracy: 0.5436 - val_loss: 1.3790
# Epoch 13/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.5755 - loss: 1.1508 - val_accuracy: 0.5615 - val_loss: 1.3102
# Epoch 14/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.5816 - loss: 1.1433 - val_accuracy: 0.5369 - val_loss: 1.3599
# Epoch 15/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.6145 - loss: 1.0710 - val_accuracy: 0.5414 - val_loss: 1.3544
# Epoch 16/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.5884 - loss: 1.1182 - val_accuracy: 0.5436 - val_loss: 1.2868
# Epoch 17/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.6297 - loss: 1.0389 - val_accuracy: 0.5369 - val_loss: 1.3312
# Epoch 18/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.6128 - loss: 1.0613 - val_accuracy: 0.5705 - val_loss: 1.2921
# Epoch 19/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.6094 - loss: 1.0703 - val_accuracy: 0.5436 - val_loss: 1.4267
# Epoch 20/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.6269 - loss: 1.0358 - val_accuracy: 0.5459 - val_loss: 1.4303
# CPU times: user 29.7 s, sys: 1.11 s, total: 30.8 s
# Wall time: 47.1 s

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# ***Observations:***
#
# 1. By leveraging augmented data, overfitting has been effectively addressed.
#
# 2. The training and validation accuracy of the aforementioned model fall within a similar range.
#
# 3. Both the training and validation data are showing poor performance, indicating that the model is now exhibiting underfitting.

# %% [markdown]
# #### Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.

from glob import glob

## find the image path for all class labels (lesions)
images_path_list = [ i for i in glob(os.path.join(data_dir_train, '*', '*.jpg')) ]

## Extract the class labels (lesions)
lesions_list = [ os.path.basename(os.path.dirname(j)) for j in glob(os.path.join(data_dir_train, '*', '*.jpg')) ]
print(len(lesions_list))
# Out:
# 2239

# %%
# Extract image path and class label in a dictionary
image_dict = dict(zip(images_path_list, lesions_list))
print(list(image_dict.items())[:5])
# Out:
# [('/content/gdrive/My Drive/Melanoma Detection Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/ISIC_0000093.jpg', 'nevus'), ('/content/gdrive/My Drive/Melanoma Detection Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/ISIC_0000097.jpg', 'nevus'), ('/content/gdrive/My Drive/Melanoma Detection Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/ISIC_0000085.jpg', 'nevus'), ('/content/gdrive/My Drive/Melanoma Detection Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/ISIC_0000091.jpg', 'nevus'), ('/content/gdrive/My Drive/Melanoma Detection Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/ISIC_0000092.jpg', 'nevus')]

# %%
# View the image path and class label in a df
lesions_df = pd.DataFrame(list(image_dict.items()), columns=['Image Path', 'Label'])
lesions_df.head()
# Out:
#                                           Image Path  Label
# 0  /content/gdrive/My Drive/Melanoma Detection As...  nevus
# 1  /content/gdrive/My Drive/Melanoma Detection As...  nevus
# 2  /content/gdrive/My Drive/Melanoma Detection As...  nevus
# 3  /content/gdrive/My Drive/Melanoma Detection As...  nevus
# 4  /content/gdrive/My Drive/Melanoma Detection As...  nevus

# %%
## Inspecting the distribution of classes in the data
lesions_df[['Label']].value_counts()
# Out:
# Label
# pigmented benign keratosis    462
# melanoma                      438
# basal cell carcinoma          376
# nevus                         357
# squamous cell carcinoma       181
# vascular lesion               139
# actinic keratosis             114
# dermatofibroma                 95
# seborrheic keratosis           77
# Name: count, dtype: int64

# %%
# Visualize the distribution of classes using a countplot

import seaborn as sns

plt.figure(figsize=(10, 8))
sns.countplot(y="Label", data=lesions_df)
plt.title('No. of images belonging to a Type v/s Types of Skin Lesion', fontsize=16)
plt.xlabel('No. of images in a particular skin lesion type', fontsize=14)
plt.ylabel('Skin Lesion Types', fontsize=14)
plt.show()

# %%
round(lesions_df[['Label']].value_counts(normalize=True)*100, 2)
# Out:
# Label
# pigmented benign keratosis    20.63
# melanoma                      19.56
# basal cell carcinoma          16.79
# nevus                         15.94
# squamous cell carcinoma        8.08
# vascular lesion                6.21
# actinic keratosis              5.09
# dermatofibroma                 4.24
# seborrheic keratosis           3.44
# Name: proportion, dtype: float64

# %% [markdown]
# #### Write your findings here:
# #### - Which class has the least number of samples?
# #### - Which classes dominate the data in terms proportionate number of samples?

# %% [markdown]
# ***Observations:***
#
# 1. A clear class imbalance is evident within the training data.
#
# 2. The class **"seborrheic keratosis"** comprises the smallest proportion of samples, accounting for approximately **3.44%**.
#
# 3. **"Pigmented benign keratosis"** and **"melanoma"** significantly outweigh other classes, representing approximately **20.63%** and **19.56%** of the data, respectively.

# %% [markdown]
# #### Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (11.0.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.66.6)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.26.4)
# Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset = str(data_dir_train) + '/'

import Augmentor

for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/gdrive/My Drive/Melanoma Detection Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7EA9F2032A10>: 100%|██████████| 500/500 [00:27<00:00, 17.95 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/gdrive/My Drive/Melanoma Detection Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7EA9F20EF820>: 100%|██████████| 500/500 [00:23<00:00, 21.21 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/gdrive/My Drive/Melanoma Detection Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7EA9EA2ABBB0>: 100%|██████████| 500/500 [00:21<00:00, 23.79 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/gdrive/My Drive/Melanoma Detection Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=919x802 at 0x7EAA50C755D0>: 100%|██████████| 500/500 [01:26<00:00,  5.77 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/gdrive/My Drive/Melanoma Detection Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7EAA1E54A080>: 100%|██████████| 500/500 [01:14<00:00,  6.75 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/gdrive/My Drive/Melanoma Detection Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7EAA3FF07E50>: 100%|██████████| 500/500 [00:20<00:00, 23.86 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/gdrive/My Drive/Melanoma Detection Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7EAA503AC4F0>: 100%|██████████| 500/500 [00:44<00:00, 11.35 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/gdrive/My Drive/Melanoma Detection Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7EAA50385DE0>: 100%|██████████| 500/500 [00:21<00:00, 23.36 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/gdrive/My Drive/Melanoma Detection Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7EAA503AC4F0>: 100%|██████████| 500/500 [00:22<00:00, 21.90 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
# Verifying the total count of images after the augmentation
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
# extracting the augmented image paths in a list
path_list_new = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list_new[:5]
# Out:
# ['/content/gdrive/My Drive/Melanoma Detection Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000229.jpg_66df4075-6eae-406b-837a-7291cb7e89a6.jpg',
#  '/content/gdrive/My Drive/Melanoma Detection Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000352.jpg_e003690a-b4ce-4aee-a380-78d13127a1f1.jpg',
#  '/content/gdrive/My Drive/Melanoma Detection Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000067.jpg_5c29904b-1757-4d0b-8fb1-6c24c82944fd.jpg',
#  '/content/gdrive/My Drive/Melanoma Detection Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000514.jpg_30c6c251-8766-411b-b766-cdd0577700ba.jpg',
#  '/content/gdrive/My Drive/Melanoma Detection Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000323.jpg_b6209909-78c7-4020-8c5e-e24bd175cb94.jpg']

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new[:5]
# Out:
# ['nevus', 'nevus', 'nevus', 'nevus', 'nevus']

# %%
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
import pandas as pd

df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Image Path','Label'])
# Use pd.concat instead of append to combine the DataFrames
new_df = pd.concat([lesions_df, df2], ignore_index=True)
# ignore_index=True ensures the index is reset for the combined DataFrame
new_df.shape
# Out:
# (6739, 2)

# %%
# View the augmented image paths and labels in a new df
new_df.head()
# Out:
#                                           Image Path  Label
# 0  /content/gdrive/My Drive/Melanoma Detection As...  nevus
# 1  /content/gdrive/My Drive/Melanoma Detection As...  nevus
# 2  /content/gdrive/My Drive/Melanoma Detection As...  nevus
# 3  /content/gdrive/My Drive/Melanoma Detection As...  nevus
# 4  /content/gdrive/My Drive/Melanoma Detection As...  nevus

# %%
# Inspecting the classes after adding 500 samples per label
new_df['Label'].value_counts()
# Out:
# Label
# pigmented benign keratosis    962
# melanoma                      938
# basal cell carcinoma          876
# nevus                         857
# squamous cell carcinoma       681
# vascular lesion               639
# actinic keratosis             614
# dermatofibroma                595
# seborrheic keratosis          577
# Name: count, dtype: int64

# %%
# Inspecting the classes (% age wise) after adding 500 samples per label
round(new_df['Label'].value_counts(normalize=True)*100, 2)
# Out:
# Label
# pigmented benign keratosis    14.28
# melanoma                      13.92
# basal cell carcinoma          13.00
# nevus                         12.72
# squamous cell carcinoma       10.11
# vascular lesion                9.48
# actinic keratosis              9.11
# dermatofibroma                 8.83
# seborrheic keratosis           8.56
# Name: proportion, dtype: float64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### Create a training dataset

# %%
# data_dir_train="path to directory with training data + data created using augmentor"

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# #### Create your model (make sure to include normalization)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# ... (previous code) ...

model = Sequential([
    augmentation_data,
    # Rescaling is now likely directly under layers (not in a 'preprocessing' submodule)
    layers.Rescaling(1./255),  # This should work now
    layers.Conv2D(16, (3, 3), padding='same', activation=tf.nn.relu),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),
    layers.Conv2D(32, (3, 3), padding='same', activation=tf.nn.relu),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),
    layers.Conv2D(64, (3, 3), padding='same', activation=tf.nn.relu),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),
    layers.Dropout(0.2),
    layers.Flatten(),
    layers.Dense(128, activation=tf.nn.relu),
    layers.Dense(target_labels)
])

# %% [markdown]
# #### Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# #### Train your model

# %%
# %%time
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 54s 268ms/step - accuracy: 0.2306 - loss: 3.7100 - val_accuracy: 0.1611 - val_loss: 11.9657
# Epoch 2/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 250ms/step - accuracy: 0.3044 - loss: 1.7882 - val_accuracy: 0.2004 - val_loss: 8.9913
# Epoch 3/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 81s 242ms/step - accuracy: 0.3463 - loss: 1.7378 - val_accuracy: 0.2925 - val_loss: 2.0708
# Epoch 4/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 250ms/step - accuracy: 0.3694 - loss: 1.6245 - val_accuracy: 0.3460 - val_loss: 1.7667
# Epoch 5/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 82s 253ms/step - accuracy: 0.3840 - loss: 1.5841 - val_accuracy: 0.2264 - val_loss: 3.8526
# Epoch 6/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 81s 247ms/step - accuracy: 0.3960 - loss: 1.5434 - val_accuracy: 0.4016 - val_loss: 1.6972
# Epoch 7/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 82s 245ms/step - accuracy: 0.4393 - loss: 1.4739 - val_accuracy: 0.4477 - val_loss: 1.4211
# Epoch 8/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 82s 243ms/step - accuracy: 0.4376 - loss: 1.4394 - val_accuracy: 0.3630 - val_loss: 2.0336
# Epoch 9/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 81s 235ms/step - accuracy: 0.4442 - loss: 1.4051 - val_accuracy: 0.3445 - val_loss: 2.0870
# Epoch 10/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 46s 273ms/step - accuracy: 0.4564 - loss: 1.3560 - val_accuracy: 0.4001 - val_loss: 1.6353
# Epoch 11/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 81s 269ms/step - accuracy: 0.4512 - loss: 1.3667 - val_accuracy: 0.3994 - val_loss: 1.6149
# Epoch 12/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 80s 259ms/step - accuracy: 0.4883 - loss: 1.3205 - val_accuracy: 0.4781 - val_loss: 1.2957
# Epoch 13/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 81s 255ms/step - accuracy: 0.4939 - loss: 1.2872 - val_accuracy: 0.3823 - val_loss: 1.8222
# Epoch 14/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 83s 260ms/step - accuracy: 0.4919 - loss: 1.2806 - val_accuracy: 0.4588 - val_loss: 1.3964
# Epoch 15/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 80s 250ms/step - accuracy: 0.5022 - loss: 1.2613 - val_accuracy: 0.4395 - val_loss: 1.4216
# Epoch 16/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 85s 267ms/step - accuracy: 0.5077 - loss: 1.2405 - val_accuracy: 0.3823 - val_loss: 2.0691
# Epoch 17/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 79s 250ms/step - accuracy: 0.5141 - loss: 1.2449 - val_accuracy: 0.4974 - val_loss: 1.3331
# Epoch 18/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 44s 263ms/step - accuracy: 0.5219 - loss: 1.2012 - val_accuracy: 0.3036 - val_loss: 3.1765
# Epoch 19/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 80s 254ms/step - accuracy: 0.5423 - loss: 1.1962 - val_accuracy: 0.5561 - val_loss: 1.2372
# Epoch 20/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 84s 269ms/step - accuracy: 0.5377 - loss: 1.1665 - val_accuracy: 0.4900 - val_loss: 1.3018
# CPU times: user 14min, sys: 49.4 s, total: 14min 50s
# Wall time: 24min 11s

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ***Observations:***
#
# 1. Implementing batch normalization in the model yielded a slight uptick in both training and validation accuracy.
# 2. Formulating an alternative model without batch normalization aims to investigate prospective improvements in accuracy.

# %% [markdown]
# #### Creating another model (without batch normalization)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# create the model
model = keras.Sequential([
    augmentation_data,
    layers.Rescaling(1./255),  # Correct way to use Rescaling
    layers.Conv2D(16, (3, 3), padding='same', activation=tf.nn.relu),
    layers.MaxPooling2D(),
    layers.Conv2D(32, (3, 3), padding='same', activation=tf.nn.relu),
    layers.MaxPooling2D(),
    layers.Conv2D(64, (3, 3), padding='same', activation=tf.nn.relu),
    layers.MaxPooling2D(),
    layers.Dropout(0.2),
    layers.Flatten(),
    layers.Dense(128, activation=tf.nn.relu),
    layers.Dense(target_labels)
])

# %% [markdown]
# #### Compiling the model

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# ModelCheckpoint callback is employed alongside the model.fit() training process to periodically save the model
# or its weights (in a checkpoint file)
checkpoint = ModelCheckpoint("model.keras", monitor="val_accuracy", save_best_only=True, mode="auto", verbose=1)

# Early stop the training when a monitored metric ceases to show improvement
earlystop = EarlyStopping(monitor="val_accuracy", patience=5, mode="auto", verbose=1)

# %% [markdown]
# #### Training the model

# %%
# %%time
# train the model
epochs = 50
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=[checkpoint, earlystop]
)
# Out:
# Epoch 1/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.1531 - loss: 2.4939
# Epoch 1: val_accuracy improved from -inf to 0.31774, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 44s 250ms/step - accuracy: 0.1533 - loss: 2.4920 - val_accuracy: 0.3177 - val_loss: 1.7938
# Epoch 2/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.3533 - loss: 1.7054
# Epoch 2: val_accuracy improved from 0.31774 to 0.41277, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 81s 243ms/step - accuracy: 0.3535 - loss: 1.7050 - val_accuracy: 0.4128 - val_loss: 1.5632
# Epoch 3/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.4476 - loss: 1.4838
# Epoch 3: val_accuracy improved from 0.41277 to 0.44989, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 81s 236ms/step - accuracy: 0.4477 - loss: 1.4836 - val_accuracy: 0.4499 - val_loss: 1.4577
# Epoch 4/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.4851 - loss: 1.3841
# Epoch 4: val_accuracy did not improve from 0.44989
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 44s 256ms/step - accuracy: 0.4851 - loss: 1.3839 - val_accuracy: 0.4098 - val_loss: 1.4841
# Epoch 5/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.4843 - loss: 1.3421
# Epoch 5: val_accuracy improved from 0.44989 to 0.50854, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 83s 265ms/step - accuracy: 0.4843 - loss: 1.3421 - val_accuracy: 0.5085 - val_loss: 1.3071
# Epoch 6/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.5140 - loss: 1.2857
# Epoch 6: val_accuracy improved from 0.50854 to 0.53452, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 80s 253ms/step - accuracy: 0.5141 - loss: 1.2856 - val_accuracy: 0.5345 - val_loss: 1.2373
# Epoch 7/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.5278 - loss: 1.2176
# Epoch 7: val_accuracy improved from 0.53452 to 0.55085, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 243ms/step - accuracy: 0.5278 - loss: 1.2175 - val_accuracy: 0.5509 - val_loss: 1.1549
# Epoch 8/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.5431 - loss: 1.1696
# Epoch 8: val_accuracy did not improve from 0.55085
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 82s 243ms/step - accuracy: 0.5432 - loss: 1.1697 - val_accuracy: 0.5345 - val_loss: 1.2215
# Epoch 9/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.5699 - loss: 1.1318
# Epoch 9: val_accuracy improved from 0.55085 to 0.56199, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 84s 255ms/step - accuracy: 0.5699 - loss: 1.1318 - val_accuracy: 0.5620 - val_loss: 1.1684
# Epoch 10/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.5893 - loss: 1.0753
# Epoch 10: val_accuracy did not improve from 0.56199
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 240ms/step - accuracy: 0.5893 - loss: 1.0753 - val_accuracy: 0.5367 - val_loss: 1.2326
# Epoch 11/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.5736 - loss: 1.1122
# Epoch 11: val_accuracy improved from 0.56199 to 0.57684, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 40s 240ms/step - accuracy: 0.5737 - loss: 1.1119 - val_accuracy: 0.5768 - val_loss: 1.1429
# Epoch 12/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.5948 - loss: 1.0375
# Epoch 12: val_accuracy improved from 0.57684 to 0.60579, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 40s 235ms/step - accuracy: 0.5948 - loss: 1.0375 - val_accuracy: 0.6058 - val_loss: 1.0551
# Epoch 13/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.6083 - loss: 1.0137
# Epoch 13: val_accuracy did not improve from 0.60579
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 241ms/step - accuracy: 0.6084 - loss: 1.0135 - val_accuracy: 0.5902 - val_loss: 1.1036
# Epoch 14/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.6501 - loss: 0.9178
# Epoch 14: val_accuracy improved from 0.60579 to 0.64439, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 243ms/step - accuracy: 0.6500 - loss: 0.9179 - val_accuracy: 0.6444 - val_loss: 0.9707
# Epoch 15/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.6457 - loss: 0.9279
# Epoch 15: val_accuracy did not improve from 0.64439
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 85s 259ms/step - accuracy: 0.6457 - loss: 0.9278 - val_accuracy: 0.6065 - val_loss: 1.0512
# Epoch 16/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.6621 - loss: 0.8723
# Epoch 16: val_accuracy did not improve from 0.64439
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 78s 234ms/step - accuracy: 0.6621 - loss: 0.8724 - val_accuracy: 0.5961 - val_loss: 1.1637
# Epoch 17/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.6715 - loss: 0.8795
# Epoch 17: val_accuracy did not improve from 0.64439
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 39s 230ms/step - accuracy: 0.6715 - loss: 0.8795 - val_accuracy: 0.6140 - val_loss: 1.0342
# Epoch 18/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.6710 - loss: 0.8641
# Epoch 18: val_accuracy improved from 0.64439 to 0.65405, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 234ms/step - accuracy: 0.6711 - loss: 0.8639 - val_accuracy: 0.6540 - val_loss: 0.9433
# Epoch 19/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.6898 - loss: 0.7888
# Epoch 19: val_accuracy improved from 0.65405 to 0.65553, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 243ms/step - accuracy: 0.6898 - loss: 0.7888 - val_accuracy: 0.6555 - val_loss: 0.9835
# Epoch 20/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.6951 - loss: 0.7971
# Epoch 20: val_accuracy improved from 0.65553 to 0.68374, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 81s 239ms/step - accuracy: 0.6952 - loss: 0.7970 - val_accuracy: 0.6837 - val_loss: 0.8413
# Epoch 21/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.7177 - loss: 0.7347
# Epoch 21: val_accuracy improved from 0.68374 to 0.69117, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 244ms/step - accuracy: 0.7176 - loss: 0.7347 - val_accuracy: 0.6912 - val_loss: 0.8627
# Epoch 22/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.7330 - loss: 0.6982
# Epoch 22: val_accuracy did not improve from 0.69117
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 83s 252ms/step - accuracy: 0.7330 - loss: 0.6982 - val_accuracy: 0.6823 - val_loss: 0.8486
# Epoch 23/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.7255 - loss: 0.7214
# Epoch 23: val_accuracy did not improve from 0.69117
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 82s 251ms/step - accuracy: 0.7255 - loss: 0.7214 - val_accuracy: 0.6741 - val_loss: 0.9366
# Epoch 24/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.7425 - loss: 0.6691
# Epoch 24: val_accuracy did not improve from 0.69117
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 40s 235ms/step - accuracy: 0.7425 - loss: 0.6692 - val_accuracy: 0.6815 - val_loss: 0.8744
# Epoch 25/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.7391 - loss: 0.6599
# Epoch 25: val_accuracy improved from 0.69117 to 0.72309, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 44s 251ms/step - accuracy: 0.7391 - loss: 0.6598 - val_accuracy: 0.7231 - val_loss: 0.7577
# Epoch 26/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.7674 - loss: 0.6126
# Epoch 26: val_accuracy did not improve from 0.72309
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 82s 252ms/step - accuracy: 0.7673 - loss: 0.6128 - val_accuracy: 0.6993 - val_loss: 0.8848
# Epoch 27/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.7635 - loss: 0.6238
# Epoch 27: val_accuracy did not improve from 0.72309
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 79s 236ms/step - accuracy: 0.7635 - loss: 0.6237 - val_accuracy: 0.7201 - val_loss: 0.7976
# Epoch 28/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.7661 - loss: 0.5998
# Epoch 28: val_accuracy did not improve from 0.72309
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 250ms/step - accuracy: 0.7661 - loss: 0.5999 - val_accuracy: 0.7231 - val_loss: 0.8266
# Epoch 29/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.7812 - loss: 0.5763
# Epoch 29: val_accuracy improved from 0.72309 to 0.73645, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 80s 237ms/step - accuracy: 0.7811 - loss: 0.5765 - val_accuracy: 0.7365 - val_loss: 0.7660
# Epoch 30/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.7914 - loss: 0.5570
# Epoch 30: val_accuracy did not improve from 0.73645
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 250ms/step - accuracy: 0.7914 - loss: 0.5571 - val_accuracy: 0.7275 - val_loss: 0.7899
# Epoch 31/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.7779 - loss: 0.5633
# Epoch 31: val_accuracy did not improve from 0.73645
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 81s 243ms/step - accuracy: 0.7779 - loss: 0.5633 - val_accuracy: 0.7327 - val_loss: 0.8258
# Epoch 32/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.7864 - loss: 0.5596
# Epoch 32: val_accuracy improved from 0.73645 to 0.73794, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 81s 240ms/step - accuracy: 0.7864 - loss: 0.5596 - val_accuracy: 0.7379 - val_loss: 0.7948
# Epoch 33/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.8042 - loss: 0.5180
# Epoch 33: val_accuracy improved from 0.73794 to 0.75427, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 240ms/step - accuracy: 0.8042 - loss: 0.5180 - val_accuracy: 0.7543 - val_loss: 0.7197
# Epoch 34/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.8164 - loss: 0.4808
# Epoch 34: val_accuracy did not improve from 0.75427
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 246ms/step - accuracy: 0.8164 - loss: 0.4809 - val_accuracy: 0.7454 - val_loss: 0.7349
# Epoch 35/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.8077 - loss: 0.4925
# Epoch 35: val_accuracy improved from 0.75427 to 0.76318, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 81s 239ms/step - accuracy: 0.8076 - loss: 0.4927 - val_accuracy: 0.7632 - val_loss: 0.7137
# Epoch 36/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.8182 - loss: 0.4860
# Epoch 36: val_accuracy improved from 0.76318 to 0.76837, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 44s 254ms/step - accuracy: 0.8182 - loss: 0.4860 - val_accuracy: 0.7684 - val_loss: 0.7024
# Epoch 37/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.8064 - loss: 0.5011
# Epoch 37: val_accuracy did not improve from 0.76837
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 82s 253ms/step - accuracy: 0.8063 - loss: 0.5012 - val_accuracy: 0.7654 - val_loss: 0.6811
# Epoch 38/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.8154 - loss: 0.4697
# Epoch 38: val_accuracy did not improve from 0.76837
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 80s 243ms/step - accuracy: 0.8154 - loss: 0.4697 - val_accuracy: 0.7535 - val_loss: 0.7270
# Epoch 39/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.8288 - loss: 0.4407
# Epoch 39: val_accuracy did not improve from 0.76837
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 246ms/step - accuracy: 0.8289 - loss: 0.4407 - val_accuracy: 0.7669 - val_loss: 0.6774
# Epoch 40/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.8356 - loss: 0.4358
# Epoch 40: val_accuracy did not improve from 0.76837
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 80s 237ms/step - accuracy: 0.8355 - loss: 0.4359 - val_accuracy: 0.7543 - val_loss: 0.7289
# Epoch 41/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.8361 - loss: 0.4267
# Epoch 41: val_accuracy improved from 0.76837 to 0.77654, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 44s 258ms/step - accuracy: 0.8360 - loss: 0.4269 - val_accuracy: 0.7765 - val_loss: 0.6651
# Epoch 42/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.8212 - loss: 0.4665
# Epoch 42: val_accuracy did not improve from 0.77654
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 81s 253ms/step - accuracy: 0.8213 - loss: 0.4664 - val_accuracy: 0.7647 - val_loss: 0.7222
# Epoch 43/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.8433 - loss: 0.4297
# Epoch 43: val_accuracy did not improve from 0.77654
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 82s 253ms/step - accuracy: 0.8433 - loss: 0.4297 - val_accuracy: 0.7699 - val_loss: 0.7194
# Epoch 44/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.8283 - loss: 0.4388
# Epoch 44: val_accuracy did not improve from 0.77654
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 79s 236ms/step - accuracy: 0.8284 - loss: 0.4388 - val_accuracy: 0.7647 - val_loss: 0.6920
# Epoch 45/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.8533 - loss: 0.3939
# Epoch 45: val_accuracy improved from 0.77654 to 0.79213, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 40s 238ms/step - accuracy: 0.8533 - loss: 0.3940 - val_accuracy: 0.7921 - val_loss: 0.6518
# Epoch 46/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.8547 - loss: 0.3838
# Epoch 46: val_accuracy did not improve from 0.79213
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 240ms/step - accuracy: 0.8546 - loss: 0.3840 - val_accuracy: 0.7342 - val_loss: 0.8741
# Epoch 47/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.8357 - loss: 0.4401
# Epoch 47: val_accuracy improved from 0.79213 to 0.80178, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 43s 253ms/step - accuracy: 0.8357 - loss: 0.4400 - val_accuracy: 0.8018 - val_loss: 0.6013
# Epoch 48/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.8601 - loss: 0.3653
# Epoch 48: val_accuracy improved from 0.80178 to 0.80549, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 242ms/step - accuracy: 0.8601 - loss: 0.3654 - val_accuracy: 0.8055 - val_loss: 0.5994
# Epoch 49/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.8559 - loss: 0.3744
# Epoch 49: val_accuracy did not improve from 0.80549
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 82s 242ms/step - accuracy: 0.8559 - loss: 0.3745 - val_accuracy: 0.7862 - val_loss: 0.6717
# Epoch 50/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.8498 - loss: 0.3853
# Epoch 50: val_accuracy did not improve from 0.80549
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 250ms/step - accuracy: 0.8498 - loss: 0.3852 - val_accuracy: 0.7884 - val_loss: 0.6832
# CPU times: user 33min 13s, sys: 2min 1s, total: 35min 14s
# Wall time: 50min 33s

# %% [markdown]
# #### Visualize the model results

# %%
model.summary()
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential_3 (Sequential)            │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling_7 (Rescaling)              │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_21 (Conv2D)                   │ (None, 180, 180, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_21 (MaxPooling2D)      │ (None, 90, 90, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_22 (Conv2D)                   │ (None, 90, 90, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_22 (MaxPooling2D)      │ (None, 45, 45, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_23 (Conv2D)                   │ (None, 45, 45, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_23 (MaxPooling2D)      │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_7 (Flatten)                  │ (None, 30976)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 128)                 │       3,965,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 9)                   │           1,161 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 11,969,405 (45.66 MB)
#  Trainable params: 3,989,801 (15.22 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 7,979,604 (30.44 MB)

# %%
# Plot the training curves

epochs_range = range(earlystop.stopped_epoch+1)

plt.figure(figsize=(15, 10))
plt.subplot(1, 2, 1)

#Plot Model Accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel(epochs_range)
plt.legend(['train', 'val'], loc='upper left')

#Plot Model Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel(epochs_range)
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# #### Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# ***Observations:***
#
# 1. The ultimate model showcases well-balanced performance, displaying no signs of underfitting or overfitting.
#
# 2. The implementation of class rebalancing has notably enhanced the model's performance across both training and validation datasets.
#
# 3. Following 37 epochs, the final model attains an accuracy of 84% on the training set and approximately 79% on the validation set.
#
# 4. The narrow divergence between training and validation accuracies underscores the robust generalization capability of the final CNN model.
#
# 5. The addition of batch normalization failed to enhance both training and validation accuracy.

# %% [markdown]
# ### Model Evaluation

# %%
# Evaluating our model on one of the instances in the test set

from tensorflow.keras.preprocessing.image import load_img

image_path_test = os.path.join(data_dir_test, class_names[1], '*')
test_image = glob(image_path_test)
test_image = load_img(test_image[-1], target_size=(180, 180, 3))
plt.imshow(test_image)
plt.grid(False)

img = np.expand_dims(test_image, axis=0)
predicted = model.predict(img)
predicted = np.argmax(predicted)
predicted_class = class_names[predicted]
print("Actual Class: " + class_names[1] +'\n'+ "Predicted Class: " + predicted_class)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step
# Actual Class: basal cell carcinoma
# Predicted Class: basal cell carcinoma
